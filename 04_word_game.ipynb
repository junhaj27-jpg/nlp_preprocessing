# %% [markdown]
# # Word Embedding을 활용한 단어 찾기 게임
#
# - Level 1. [Semantle](https://semantle.com/) 흉내내기
# - Level 2. Semantle의 한국어 버전을 만들어보기
# - Level 3. 단어 `A:B=C:?` 여기서 ? 맞추기 ([한국어 임베딩 확인](https://word2vec.kr/search/) + Semantle)

# %%
! pip install gensim numpy
# Out:
# Requirement already satisfied: gensim in c:\Users\Playdata\anaconda3\envs\nlp_env\Lib\site-packages (4.4.0)
# Requirement already satisfied: numpy in c:\Users\Playdata\anaconda3\envs\nlp_env\Lib\site-packages (2.4.2)
# Requirement already satisfied: scipy>=1.7.0 in c:\Users\Playdata\anaconda3\envs\nlp_env\Lib\site-packages (from gensim) (1.17.1)
# Requirement already satisfied: smart_open>=1.8.1 in c:\Users\Playdata\anaconda3\envs\nlp_env\Lib\site-packages (from gensim) (7.5.1)
# Requirement already satisfied: wrapt in c:\Users\Playdata\anaconda3\envs\nlp_env\Lib\site-packages (from smart_open>=1.8.1->gensim) (2.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from gensim.models import Word2Vec

# 예제 학습 데이터
sentences = [
    ["king","queen","man","woman"],
    ["paris","france","london","england"],
    ["apple","fruit","banana","orange"],
    ["dog","cat","animal"],
    ["car","bus","train","transport"]
]

# Word2Vec 모델 학습
model = Word2Vec(sentences, vector_size=50, window=2, min_count=1)

# 코사인 유사도
def cosine_sim(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

target = "king"

while True:

    guess = input("추측 단어: ").strip()

    if guess not in model.wv or target not in model.wv:
        print("사전에 없는 단어")
        continue

    sim = cosine_sim(model.wv[guess], model.wv[target]) * 100

    print(f"유사도: {sim:.2f}")

    if guess == target:
        print("정답!")
        break

# %%
# !pip install gensim numpy
